# %% [markdown]
# <a href="https://colab.research.google.com/github/ParzivalWins/PlayingWithNotebooks/blob/Development/Practice_Python_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Jupyter Test

# %%
import pandas

# %% [markdown]
# ![Screen Shot 2020-10-22 at 1.47.39 PM.png](data:image/png;base64,...)

# %%
y = [1, 3, 5, 11]

# %% [markdown]
# ![implementing-agile-project-management.png](data:image/png;base64,...)

# %%
y.reverse()

# %%
print(y)
# Out:
# [11, 5, 3, 1]

# %%
x = ['c', 'b', 'a', 'a']

# %%
print(x.count("a"))
# Out:
# 2

# %%
import numpy as np

# %%
m = np.array([2,4,6])

# %%
n = np.array([2, True, False])

# %%
print(m +n)
# Out:
# [4 5 6]

# %%
x = np.array([3, 4, True, False, "5.2"])

# %%
print (x)
# Out:
# ['3' '4' 'True' 'False' '5.2']

# %%
x = [4, 4, 2, 1, 1, 6]

# %%
print (x[5] + x[4])
# Out:
# 7

# %%
q = [8, 36, 43, 50]

# %%
print (len(q))
# Out:
# 4
